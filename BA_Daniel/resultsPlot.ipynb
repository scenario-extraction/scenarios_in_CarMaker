# %%
##### plot small 
import matplotlib.pyplot as plt

steps = [120000,150000,180000,210000,240000,270000,300000,330000,360000,390000,420000,450000,480000,510000,540000,570000,600000,630000,660000,690000,720000,750000,780000,810000,840000,870000,900000,930000,960000,990000]
MOTA = [0.5848306567021784,0.6128160279853713,0.6538400381618699,0.677373191286373,0.6951820639211321,0.6892987756400064,0.6999522976625855,0.707425663857529,0.6902528223882971,0.6902528223882971,0.7147400222610908,0.7085387183972014,0.7193512482111624,-0.35983463189696296,0.7215773572905073,0.728255684528542,0.7093337573541103,0.7241214819526156,0.7160120845921449,0.7148990300524726,0.7150580378438544,0.7258705676578152,0.730322785816505,0.7336619494355223,0.7128319287645095,0.7179201780887263,0.7241214819526156,0.7236444585784703,0.7315948481475592,0.7199872793766895]
MOTP = [0.16239195955129795,0.16185828912941083,0.1627233744761305,0.16174713580607322,0.1626737334572176,0.1616283352376742,0.16184932864648563,0.16223143831675543,0.1613624823367839,0.16325679727989906,0.16147919613421816,0.1597494078951455,0.15925201183431684,0.16747395106814933,0.16203226874850934,0.16154295530017385,0.161942662667502,0.16249835061082168,0.16226288949438797,0.16211654462664152,0.16183532202477938,0.16181832709416283,0.16123436753092427,0.16170493450648943,0.1624285014222548,0.161251160733112,0.16032808278904792,0.1616183358395737,0.16190266383998744,0.16137357636219546]
mAP = [0.32763871391600785,0.33639472308031826,0.3489268591904882,0.3545985743206773,0.3623806289504656,0.35912563077134074,0.36344895474201666,0.37007644593273115,0.3659503873629701,0.36655468178269535,0.3683891265589665,0.36859875191885116,0.3730625935585055,0.28309378270241353,0.37241083537938696,0.3717082646976776,0.36891679908039327,0.37354017384253546,0.374153673592069,0.37266594377590495,0.3730481592707387,0.3725250883751643,0.37383014205159365,0.37321647197284713,0.37174708609192586,0.3736511216799905,0.37551117870434675,0.37544886521726784,0.37461521377336554,0.37339829811870223]


plt.plot([x / 30000 for x in steps], mAP)
plt.axis([0, 1000000/30000, 0.2, 0.45])
plt.xlabel("Epoche")
plt.ylabel("mAP")
plt.show()

plt.plot([x / 30000 for x in steps], MOTP)
plt.axis([0, 1000000/30000, 0.15, 0.2])
plt.xlabel("Epoche")
plt.ylabel("MOTP")
plt.show()

plt.plot([x / 30000 for x in steps], MOTA)
plt.axis([0, 1000000/30000, 0.0, 0.8])
plt.xlabel("Epoche")
plt.ylabel("MOTA")
plt.show()

index = 26
print("Values at: "+str(steps[index]/30000))
print(mAP[index])
print(MOTP[index])
print(MOTA[index])


index = 28
print("Values at: "+str(steps[index]/30000))
print(mAP[index])
print(MOTP[index])
print(MOTA[index])
# Out:
# Values at: 30.0
# 0.37551117870434675
# 0.16032808278904792
# 0.7241214819526156
# Values at: 32.0
# 0.37461521377336554
# 0.16190266383998744
# 0.7315948481475592

# %%
##### plot middle
steps = [120000,180000,210000,240000,270000,300000,330000,360000,390000,420000,480000,510000,540000,570000,600000,630000,660000,690000,720000,750000,780000,810000,840000,870000,900000,930000,960000,990000]
MOTA = [0.31026365348399243,0.3851224105461394,0.355225988700565,0.42608286252354044,0.36087570621468923,0.3588747645951036,0.3830037664783428,0.38912429378531077,0.40925141242937857,0.3721751412429378,0.4701035781544256,0.29096045197740117,0.35228342749529196,0.5402542372881356,0.5262476459510358,0.5371939736346516,0.5311911487758945,0.530367231638418,0.530484934086629,0.5384887005649718,0.5417843691148776,0.544256120527307,0.528837099811676,0.5326035781544256,0.5371939736346516,0.5368408662900188,0.542725988700565,0.5341337099811676]
MOTP = [0.18276668977854593,0.18016190970620877,0.17854866403443687,0.1811168339756954,0.1786011020805784,0.18057155022009472,0.17999985015069275,0.1773681047367196,0.17629922222629696,0.17658107825549377,0.17632353486355376,0.17881544010197248,0.17543167738934487,0.161585186117836,0.1620029141960782,0.16253748818890654,0.16232605394737673,0.16218438493129347,0.1618955052844364,0.1618793949505502,0.1612966407420438,0.1617686845947125,0.16249426174039264,0.1613148277325285,0.16038947959849842,0.16168074509201583,0.1619680159925234,0.16143761845997873]
mAP = [0.25672185618652515,0.2639520286722541,0.25923950913068655,0.2675256892477065,0.25997195267323214,0.25730400676010595,0.2630391112222729,0.27094872672072007,0.2696463370189118,0.2626663604760499,0.28340956963878206,0.2503947013346682,0.2605376910600737,0.30465147395732534,0.3027778546965204,0.3059252840545766,0.3061943800986654,0.3053977870951385,0.3058301517938243,0.30541720581073517,0.3062418594281857,0.3058169967974581,0.30486431681813453,0.30621226688306225,0.30748488036859584,0.30736994064874096,0.30696666513935456,0.30608264595829043]

plt.plot([x / 30000 for x in steps], mAP)
plt.axis([0, 1000000/30000, 0.2, 0.4])
plt.xlabel("Epoche")
plt.ylabel("mAP")
plt.show()

plt.plot([x / 30000 for x in steps], MOTP)
plt.axis([0, 1000000/30000, 0.15, 0.2])
plt.xlabel("Epoche")
plt.ylabel("MOTP")
plt.show()

plt.plot([x / 30000 for x in steps], MOTA)
plt.axis([0, 1000000/30000, 0.2, 0.6])
plt.xlabel("Epoche")
plt.ylabel("MOTA")
plt.show()


index = 24
print("Values at: "+str(steps[index]/30000))
print(mAP[index])
print(MOTP[index])
print(MOTA[index])


index = 19
print("Values at: "+str(steps[index]/30000))
print(mAP[index])
print(MOTP[index])
print(MOTA[index])
# Out:
# Values at: 30.0
# 0.30748488036859584
# 0.16038947959849842
# 0.5371939736346516
# Values at: 25.0
# 0.30541720581073517
# 0.1618793949505502
# 0.5384887005649718

# %%
## plot large 


steps = [180000,210000,240000,270000,300000,330000,390000,420000,450000,480000,510000,540000,570000,600000,630000,660000,690000,720000,750000,780000,810000,840000,870000,900000,930000,960000,990000]
MOTA = [0.18038686459739095,0.16520467836257313,0.15778227620332885,0.13124156545209176,0.14080071974808817,0.1616059379217274,0.07928475033738192,0.0802968960863698,0.136302294197031,0.11707152496626183,0.2782276203328835,0.06072874493927127,0.08704453441295545,0.07995951417004044,0.07793522267206476,0.12044534412955465,0.12089518668466037,0.08625730994152048,0.06657669815564549,0.08614484930274402,0.10874943769680612,0.00877192982456143,0.09188034188034189,0.030364372469635637,0.02597840755735492,0.08265856950067474,0.05937921727395412]
MOTP = [0.17806759576248657,0.17737754386246687,0.17625160343511798,0.17587034471607416,0.17729597567131955,0.17718235593116538,0.1769772704650785,0.17765695517698077,0.1763654367817664,0.17616705201751337,0.17882153784867483,0.17577950235266304,0.17657627549395577,0.1761108571357371,0.17661621412700065,0.17643718024224314,0.1770919668761715,0.1754681013966923,0.17824466499369188,0.17547468692233933,0.17696623398275843,0.17572122686522232,0.17582425927714923,0.1771775012110285,0.1768016162586993,0.17722815546680537,0.17643556584215445]
mAP = [0.21147875280784323,0.20990167224448245,0.21077874070832883,0.20407084584387133,0.20576490182994425,0.20735224343902636,0.1967900215127321,0.19526777927667788,0.19863005512989895,0.20102025183460795,0.2448170462771679,0.19009202155960886,0.19417285811722265,0.19549196063868343,0.19672884761636064,0.19940282530045278,0.20374020327754147,0.1970964908612847,0.1949287092011488,0.19717579775234642,0.19603702135057188,0.18304258618726826,0.19832416202485928,0.18792262030493004,0.1917539992624075,0.19570313827711494,0.19297788490474313]

plt.plot([x / 30000 for x in steps], mAP)
plt.axis([0, 1000000/30000, 0.1, 0.3])
plt.xlabel("Epoche")
plt.ylabel("mAP")
plt.show()

plt.plot([x / 30000 for x in steps], MOTP)
plt.axis([0, 1000000/30000, 0.15, 0.2])
plt.xlabel("Epoche")
plt.ylabel("MOTP")
plt.show()

plt.plot([x / 30000 for x in steps], MOTA)
plt.axis([0, 1000000/30000, 0.0, 0.3])
plt.xlabel("Epoche")
plt.ylabel("MOTA")
plt.show()





index = 10
print("Values at: "+str(steps[index]/30000))
print(mAP[index])
print(MOTP[index])
print(MOTA[index])


index = 16
print("Values at: "+str(steps[index]/30000))
print(mAP[index])
print(MOTP[index])
print(MOTA[index])
# Out:
# Values at: 17.0
# 0.2448170462771679
# 0.17882153784867483
# 0.2782276203328835
# Values at: 23.0
# 0.20374020327754147
# 0.1770919668761715
# 0.12089518668466037
